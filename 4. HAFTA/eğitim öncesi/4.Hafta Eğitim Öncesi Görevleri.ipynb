# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
rehber= {
    "ahmet": "0532 678 13 19",
    "tuba": "0555 056 0854",
    "seyhan": "0507 148 22 12"
}        
kişi=input("Lütfen numarasını öğrenmek istediğiniz kişinin adını girin:")
print(f" {kişi} isimli kişinin numarası: {rehber[]}")
# Out:
#   Cell In[27], line 7
#     print(f" {kişi} isimli kişinin numarası: {rehber[]}")
#                                               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
calisanlar={
    "Tuba Gümüş":["Memleket. İstanbul", "Yaş: 16", "Görev: Öğrenci"],
    "Emre Kaya":["Memleket: Sakarya", "Yaş : 17", "Görev: Öğrenci"],
    "Mehmet Yağız": ["Memleket: Adana", " Yaş: 40", "Görev: Direktör"]
}
kişi= input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin:")
print(f"{kişi} isimli kişinin memleketi: {calisanlar[kişi][0]} yaşı: {calisanlar[kişi[1]]} görevi: {calisanlar[kişi][2]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 7
#       1 calisanlar={
#       2     "Tuba Gümüş":["Memleket. İstanbul", "Yaş: 16", "Görev: Öğrenci"],
#       3     "Emre Kaya":["Memleket: Sakarya", "Yaş : 17", "Görev: Öğrenci"],
#       4     "Mehmet Yağız": ["Memleket: Adana", " Yaş: 40", "Görev: Direktör"]
#       5 }
#       6 kişi= input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin:")
# ----> 7 print(f"{kişi} isimli kişinin memleketi: {calisanlar[kişi][0]} yaşı: {calisanlar[kişi[1]]} görevi: {calisanlar[kişi][2]}")
#
# KeyError: 'u'

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
öğrenci= {"Emre": [54,80,90], "Tuba": [45,65,100], "Mehmet": [72,66,28]}
bilgi= input("Lütfen notlarını grmek istediğiniz öğrencinin adını girin:")
ortalama=sum(öğrenci[bilgi])/3
print(f"{bilgi} isimli öğrencinin \n 1. sınav notu: {öğrenci[bilgi][0]} \n 2. sınav notu: {öğrenci [bilgi][1]} \n 3. sınav notu: {öğrenci [bilgi][2]}")
# Out:
# Mehmet isimli öğrencinin
#  1. sınav notu: 72
#  2. sınav notu: 66
#  3. sınav notu: 28

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
liste=["Bmw", "Mercedes", "Opel", "Mazda"]

# 2-  Liste Kaç elemanlıdır ?
(len(liste))

# 3-  Listenin ilk ve son elemanını yazınız.
(liste[0]) 
(liste[-1])

# 4-  Mazda değerini Toyota ile değiştirin.
liste.remove("Mazda")
liste.append("Toyota")

# 5-  Listenin -2 indeksindeki değer nedir ?
liste.index("Opel")

# 6-  Listenin ilk 3 elemanını alın.
liste[:3]
# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
liste[-2:]=["Toyota", "Renault"]

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
liste.append("Audi")
liste.append("Nissan")
# 9- Listenin son elemanını silin.
liste.pop()
# 10- Liste elemanlarını tersten yazdırınız.
liste.reverse()



# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 




# 12- Liste elemanlarını ekrana yazdırınız.



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]



# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names.append("Cenk")


# 14-  "Sena" değerini listenin başına ekleyiniz.
names.insert(0, "Sena")

# 15-  "Deniz" ismini listeden siliniz.
names.remove("Deniz")

# 16-  "Ali" listenin bir elemanı mıdır ?
names.index("Ali")

# 17-  Liste elemanlarını ters çevirin.
names.reverse()
years.reverse()

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names.sort()


# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years.sort()

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
str.split(",")

# 21- years dizisinde kaç tane 1998 değeri vardır ?
years.coumt("1998")

# 22- years dizisinin tüm elemanlarını siliniz.
years.clear()

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
marka1=input("1. marka ismini giriniz")
marka2=input("2.marka ismini griniz")
marka3=input("3. marka ismini giriniz")
liste=[marka1, marka2, marka3]
# Out:
# 4
# Bmw
# Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# 2
# ['Bmw', 'Mercedes', 'Opel', 'Toyota', 'Audi', 'Nissan']
# ['Audi', 'Toyota', 'Opel', 'Mercedes', 'Bmw']
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 86
#      83 years.clear()
#      85 # 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
# ---> 86 marka1=input("1. marka ismini giriniz")
#      87 marka2=input("2.marka ismini griniz")
#      88 marka3=input("3. marka ismini giriniz")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
