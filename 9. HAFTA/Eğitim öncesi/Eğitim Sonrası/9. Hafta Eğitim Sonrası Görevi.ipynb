# %% [markdown]
# # Problem 1
#
# Kumanda isminde bir sınıf oluşturarak aşağıdaki işlemleri yapmasını sağlayan fonksiyonları sınıf içerisinde yazalım.
# 1. Tv Aç
# 2. Tv Kapat
# 3. Ses Ayarları
# 4. Kanal Ekle
# 5. Kanal Sayısını Öğrenme
# 6. Rastgele Kanala Geçme
# 7. Televizyon Bilgileri
#
#
# Kumandayı kapatmak için q tuşuna basılmalı ve diğer durumlarda hangi işlemi yapmak istediği sorulmalıdır. Her işlemde gerekli fonksiyonunun sınıf içerisinden çağırılması gerekmektedir.
#
# random ve time kütüphanesini araştırarak kullanabilirsiniz.
#
# Kendi istediğiniz özellikleri eklemekte serbetsiniz.

# %%
import random
import time

class remoteControl():
    def __init__ (self, tvDurum="Close",tvSoundLevel="0",channelList=["Now","TRT","Tv8","Star"],channel="Tv8"):
        self.tvDurum=tvDurum
        self.tvSoundLevel= tvSoundLevel
        self.channelList=channelList
        self.channel=channel
    def tvOpen(self):
        if (self.tvDurum=="Open"):
            print("Tv is already on")
        else:
            print("Tv is opening")
            self.tvDurum="Open"
    def tvClose(self):
         if (self.tvDurum=="Close"):
            print("Tv is already off")
         else:
            print("Tv is closing")
            self.tvDurum="Close"
    def SoundSettings(self):
        while True:
            answer=input("type < to decrease volume, type > to increase volume, type exit to exit")
            if answer=="<":
                if(self.tvSoundLevel!=0):
                    self.tvSoundLevel-=1
                    print("Sound Level:", self.tvSoundLevel)
                elif answer==">":
                    if(self.tvSoundLevel!=20):
                        self.tvSoundLevel+=1
                        print("Sound Level:", self.tvSoundLevel)
                else:
                    print("Volume updated.  Sound Level:", self.tvSoundLevel)
                    break
    def AddChannel(self, channelName):
        print("Adding Channel...")
        time.sleep(2)
        self.channelList.append(channelName)
        print("Channel Added")
    def randomChannel(self):
        random=random.randint(0,len(self.channelList)-1)
        self.channel=self.channelList[random]
        print("Current Channel", self.channel)
    def __len__(self):
        return len(self.channelList)
    def __str__(self):
        return f"Tv: {self.tvDurum}\n Tv Sound Level {self.tvSoundLevel}\n Channel List: {self. channelList}\n Current Channel: {self.channel}"
    
remoteControl= remoteControl()

print(""" 
Television App
1-Open Tv
2-Close Tv
3-Sound Settings
4- Add Channel
5-Learn Channel Number
6- Go to a Random Channel
7- Television Information
please press 'q' to exit.
""")

while True:
    operation=input("Please write the number of operation that you want to do")
    if operation=="q":
        print("App is closing.")
        break
    elif operation=="1":
        remoteControl.tvOpen()
    elif operation=="2":
        remoteControl.tvClose()
    elif operation=="3":
        remoteControl.SoundSettings()
    elif operation=="4":
        channelName=input("please write channel names by divide with ',' ")
channelList=channelName.split(",")
        for i in channelList:
            remoteControl.AddChannel(i)
    elif operation=="5":
# Out:
#
# Television App
# 1-Open Tv
# 2-Close Tv
# 3-Sound Settings
# 4- Add Channel
# 5-Learn Channel Number
# 6- Go to a Random Channel
# 7- Television Information
# please press 'q' to exit.
#
# App is closing.
